# %% [markdown]
#                         Project Title: Analyzing Airline Passenger Satisfaction

# %% [markdown]
# 1.Inroduction
# Understanding passenger satisfaction is crucial for airlines.Its very important for imporving the services of Airline thats help the passenger for happy and healthy journey.

# %%
import pandas as pd # that library working with dataset
import numpy as np# that library working  with array (numerical data)
import matplotlib.pyplot as plt # that library working with plots users to create numerous and diverse plot.
import seaborn as sns #that widely use for data visualization  and statistical graphics
import warnings
warnings.filterwarnings("ignore")# it suppress all warnings generated by program code
#value = ignore (That never print matching warnings)

# %% [markdown]
# 2. Data Collection and Exploration

# %%
passenger=pd.read_csv("Airlinedata.csv")
passenger
# Airlinedata.csv file contain different types of coulmns that contain airlinepassenger information.
# Out:
#             id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0        70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1         5047    Male  disloyal Customer   25  Business travel  Business
# 2       110028  Female     Loyal Customer   26  Business travel  Business
# 3        24026  Female     Loyal Customer   25  Business travel  Business
# 4       119299    Male     Loyal Customer   61  Business travel  Business
# ...        ...     ...                ...  ...              ...       ...
# 103899   94171  Female  disloyal Customer   23  Business travel       Eco
# 103900   73097    Male     Loyal Customer   49  Business travel  Business
# 103901   68825    Male  disloyal Customer   30  Business travel  Business
# 103902   54173  Female  disloyal Customer   22  Business travel       Eco
# 103903   62567    Male     Loyal Customer   27  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 0                   460                      3
# 1                   235                      3
# 2                  1142                      2
# 3                   562                      2
# 4                   214                      3
# ...                 ...                    ...
# 103899              192                      2
# 103900             2347                      4
# 103901             1995                      1
# 103902             1000                      1
# 103903             1723                      1
#
#         Departure/Arrival time convenient  Ease of Online booking  ...  \
# 0                                       4                       3  ...
# 1                                       2                       3  ...
# 2                                       2                       2  ...
# 3                                       5                       5  ...
# 4                                       3                       3  ...
# ...                                   ...                     ...  ...
# 103899                                  1                       2  ...
# 103900                                  4                       4  ...
# 103901                                  1                       1  ...
# 103902                                  1                       1  ...
# 103903                                  3                       3  ...
#
#         Inflight entertainment  On-board service  Leg room service  \
# 0                            5                 4                 3
# 1                            1                 1                 5
# 2                            5                 4                 3
# 3                            2                 2                 5
# 4                            3                 3                 4
# ...                        ...               ...               ...
# 103899                       2                 3                 1
# 103900                       5                 5                 5
# 103901                       4                 3                 2
# 103902                       1                 4                 5
# 103903                       1                 1                 1
#
#         Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0                      4                4                 5            5
# 1                      3                1                 4            1
# 2                      4                4                 4            5
# 3                      3                1                 4            2
# 4                      4                3                 3            3
# ...                  ...              ...               ...          ...
# 103899                 4                2                 3            2
# 103900                 5                5                 5            4
# 103901                 4                5                 5            4
# 103902                 1                5                 4            1
# 103903                 4                4                 3            1
#
#         Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0                               25                      18.0
# 1                                1                       6.0
# 2                                0                       0.0
# 3                               11                       9.0
# 4                                0                       0.0
# ...                            ...                       ...
# 103899                           3                       0.0
# 103900                           0                       0.0
# 103901                           7                      14.0
# 103902                           0                       0.0
# 103903                           0                       0.0
#
#                    satisfaction
# 0       neutral or dissatisfied
# 1       neutral or dissatisfied
# 2                     satisfied
# 3       neutral or dissatisfied
# 4                     satisfied
# ...                         ...
# 103899  neutral or dissatisfied
# 103900                satisfied
# 103901  neutral or dissatisfied
# 103902  neutral or dissatisfied
# 103903  neutral or dissatisfied
#
# [103904 rows x 24 columns]

# %% [markdown]
# a. Find first five passenger detail information regarding Airline Service

# %%
passenger.head()
# Thats show a first five rows by default
# Out:
#        id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0   70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1    5047    Male  disloyal Customer   25  Business travel  Business
# 2  110028  Female     Loyal Customer   26  Business travel  Business
# 3   24026  Female     Loyal Customer   25  Business travel  Business
# 4  119299    Male     Loyal Customer   61  Business travel  Business
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
# 3              562                      2                                  5
# 4              214                      3                                  3
#
#    Ease of Online booking  ...  Inflight entertainment  On-board service  \
# 0                       3  ...                       5                 4
# 1                       3  ...                       1                 1
# 2                       2  ...                       5                 4
# 3                       5  ...                       2                 2
# 4                       3  ...                       3                 3
#
#    Leg room service  Baggage handling  Checkin service  Inflight service  \
# 0                 3                 4                4                 5
# 1                 5                 3                1                 4
# 2                 3                 4                4                 4
# 3                 5                 3                1                 4
# 4                 4                 4                3                 3
#
#    Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0            5                          25                      18.0
# 1            1                           1                       6.0
# 2            5                           0                       0.0
# 3            2                          11                       9.0
# 4            3                           0                       0.0
#
#               satisfaction
# 0  neutral or dissatisfied
# 1  neutral or dissatisfied
# 2                satisfied
# 3  neutral or dissatisfied
# 4                satisfied
#
# [5 rows x 24 columns]

# %% [markdown]
# b. Find Last five Passenger detail information regarding Airline Services

# %%
passenger.tail()
#Dispaly last five passenger information regarding Airline Service .
# Out:
#            id  Gender      Customer Type  Age   Type of Travel     Class  \
# 103899  94171  Female  disloyal Customer   23  Business travel       Eco
# 103900  73097    Male     Loyal Customer   49  Business travel  Business
# 103901  68825    Male  disloyal Customer   30  Business travel  Business
# 103902  54173  Female  disloyal Customer   22  Business travel       Eco
# 103903  62567    Male     Loyal Customer   27  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 103899              192                      2
# 103900             2347                      4
# 103901             1995                      1
# 103902             1000                      1
# 103903             1723                      1
#
#         Departure/Arrival time convenient  Ease of Online booking  ...  \
# 103899                                  1                       2  ...
# 103900                                  4                       4  ...
# 103901                                  1                       1  ...
# 103902                                  1                       1  ...
# 103903                                  3                       3  ...
#
#         Inflight entertainment  On-board service  Leg room service  \
# 103899                       2                 3                 1
# 103900                       5                 5                 5
# 103901                       4                 3                 2
# 103902                       1                 4                 5
# 103903                       1                 1                 1
#
#         Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 103899                 4                2                 3            2
# 103900                 5                5                 5            4
# 103901                 4                5                 5            4
# 103902                 1                5                 4            1
# 103903                 4                4                 3            1
#
#         Departure Delay in Minutes  Arrival Delay in Minutes  \
# 103899                           3                       0.0
# 103900                           0                       0.0
# 103901                           7                      14.0
# 103902                           0                       0.0
# 103903                           0                       0.0
#
#                    satisfaction
# 103899  neutral or dissatisfied
# 103900                satisfied
# 103901  neutral or dissatisfied
# 103902  neutral or dissatisfied
# 103903  neutral or dissatisfied
#
# [5 rows x 24 columns]

# %% [markdown]
# c. Find feedback data regarding Airline Service of any random passenger

# %%
passenger.sample(10)
# Take a information of any random 10 passenger by using sample
# Out:
#            id  Gender      Customer Type  Age   Type of Travel     Class  \
# 35946   79782  Female     Loyal Customer   60  Personal Travel  Business
# 63060   45266  Female     Loyal Customer   48  Business travel  Business
# 13167   78255    Male     Loyal Customer   52  Business travel  Business
# 75010   14208  Female  disloyal Customer   29  Business travel       Eco
# 44121   11683  Female     Loyal Customer   63  Personal Travel  Business
# 66963   64369    Male     Loyal Customer   29  Personal Travel       Eco
# 62512   29377  Female     Loyal Customer   45  Business travel  Business
# 29219   19048    Male  disloyal Customer   20  Business travel       Eco
# 102515  60182  Female     Loyal Customer   59  Personal Travel       Eco
# 8552    15179    Male     Loyal Customer   41  Personal Travel       Eco
#
#         Flight Distance  Inflight wifi service  \
# 35946              1010                      1
# 63060               290                      0
# 13167               903                      2
# 75010               620                      1
# 44121               429                      1
# 66963              1192                      2
# 62512              2457                      3
# 29219               304                      3
# 102515             1120                      2
# 8552                416                      3
#
#         Departure/Arrival time convenient  Ease of Online booking  ...  \
# 35946                                   4                       1  ...
# 63060                                   0                       0  ...
# 13167                                   1                       1  ...
# 75010                                   2                       1  ...
# 44121                                   4                       1  ...
# 66963                                   4                       2  ...
# 62512                                   2                       2  ...
# 29219                                   2                       3  ...
# 102515                                  4                       2  ...
# 8552                                    4                       3  ...
#
#         Inflight entertainment  On-board service  Leg room service  \
# 35946                        2                 2                 1
# 63060                        5                 5                 5
# 13167                        2                 2                 2
# 75010                        1                 4                 3
# 44121                        3                 3                 1
# 66963                        3                 1                 1
# 62512                        2                 5                 4
# 29219                        2                 2                 3
# 102515                       4                 4                 2
# 8552                         3                 2                 4
#
#         Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 35946                  2                2                 2            5
# 63060                  5                3                 5            5
# 13167                  2                3                 2            2
# 75010                  3                1                 4            1
# 44121                  3                3                 3            3
# 66963                  5                5                 2            3
# 62512                  4                3                 4            3
# 29219                  3                4                 2            2
# 102515                 3                4                 4            3
# 8552                   3                5                 2            3
#
#         Departure Delay in Minutes  Arrival Delay in Minutes  \
# 35946                            0                       0.0
# 63060                            0                       0.0
# 13167                            0                       0.0
# 75010                          143                     133.0
# 44121                            0                       0.0
# 66963                           54                      43.0
# 62512                           25                      24.0
# 29219                           91                     119.0
# 102515                           0                       0.0
# 8552                             0                       0.0
#
#                    satisfaction
# 35946   neutral or dissatisfied
# 63060                 satisfied
# 13167   neutral or dissatisfied
# 75010   neutral or dissatisfied
# 44121   neutral or dissatisfied
# 66963   neutral or dissatisfied
# 62512   neutral or dissatisfied
# 29219   neutral or dissatisfied
# 102515  neutral or dissatisfied
# 8552    neutral or dissatisfied
#
# [10 rows x 24 columns]

# %% [markdown]
# c.Define the different type sof datatypes invovle in this Dataset

# %%
passenger.dtypes
# Out:
# id                                     int64
# Gender                                object
# Customer Type                         object
# Age                                    int64
# Type of Travel                        object
# Class                                 object
# Flight Distance                        int64
# Inflight wifi service                  int64
# Departure/Arrival time convenient      int64
# Ease of Online booking                 int64
# Gate location                          int64
# Food and drink                         int64
# Online boarding                        int64
# Seat comfort                           int64
# Inflight entertainment                 int64
# On-board service                       int64
# Leg room service                       int64
# Baggage handling                       int64
# Checkin service                        int64
# Inflight service                       int64
# Cleanliness                            int64
# Departure Delay in Minutes             int64
# Arrival Delay in Minutes             float64
# satisfaction                          object
# dtype: object

# %% [markdown]
# d. Find total number of entries of passenger in Airline Passenger Satisfaction Survey

# %%
passenger.shape
# 103904 total entries of passenger in Airline passenger Satisfaction Survey
# Out:
# (103904, 24)

# %% [markdown]
# e. Find the number of coulmns, range index, coulmn index, datatypes,check not null entry

# %%
passenger.info()
#info() function is used to get a concise summary of the dataframe. It comes really handy when doing exploratory analysis of the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   id                                 103904 non-null  int64
#  1   Gender                             103904 non-null  object
#  2   Customer Type                      103904 non-null  object
#  3   Age                                103904 non-null  int64
#  4   Type of Travel                     103904 non-null  object
#  5   Class                              103904 non-null  object
#  6   Flight Distance                    103904 non-null  int64
#  7   Inflight wifi service              103904 non-null  int64
#  8   Departure/Arrival time convenient  103904 non-null  int64
#  9   Ease of Online booking             103904 non-null  int64
#  10  Gate location                      103904 non-null  int64
#  11  Food and drink                     103904 non-null  int64
#  12  Online boarding                    103904 non-null  int64
#  13  Seat comfort                       103904 non-null  int64
#  14  Inflight entertainment             103904 non-null  int64
#  15  On-board service                   103904 non-null  int64
#  16  Leg room service                   103904 non-null  int64
#  17  Baggage handling                   103904 non-null  int64
#  18  Checkin service                    103904 non-null  int64
#  19  Inflight service                   103904 non-null  int64
#  20  Cleanliness                        103904 non-null  int64
#  21  Departure Delay in Minutes         103904 non-null  int64
#  22  Arrival Delay in Minutes           103594 non-null  float64
#  23  satisfaction                       103904 non-null  object
# dtypes: float64(1), int64(18), object(5)
# memory usage: 19.0+ MB

# %% [markdown]
# f. Display satistical information like mean ,median, mode,quartile (Q1 , Q2, Q3) ,standard deviation, minimum and maximum and total number of entries in the Airline Passenger Satsifaction Survey.

# %%
passenger.describe()
#describe() method is used for calculating some statistical data like percentile, mean and std of the numerical values of the Series or DataFrame.
# Out:
#                   id            Age  Flight Distance  Inflight wifi service  \
# count  103904.000000  103904.000000    103904.000000          103904.000000
# mean    64924.210502      39.379706      1189.448375               2.729683
# std     37463.812252      15.114964       997.147281               1.327829
# min         1.000000       7.000000        31.000000               0.000000
# 25%     32533.750000      27.000000       414.000000               2.000000
# 50%     64856.500000      40.000000       843.000000               3.000000
# 75%     97368.250000      51.000000      1743.000000               4.000000
# max    129880.000000      85.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      103904.000000           103904.000000
# mean                            3.060296                2.756901
# std                             1.525075                1.398929
# min                             0.000000                0.000000
# 25%                             2.000000                2.000000
# 50%                             3.000000                3.000000
# 75%                             4.000000                4.000000
# max                             5.000000                5.000000
#
#        Gate location  Food and drink  Online boarding   Seat comfort  \
# count  103904.000000   103904.000000    103904.000000  103904.000000
# mean        2.976883        3.202129         3.250375       3.439396
# std         1.277621        1.329533         1.349509       1.319088
# min         0.000000        0.000000         0.000000       0.000000
# 25%         2.000000        2.000000         2.000000       2.000000
# 50%         3.000000        3.000000         3.000000       4.000000
# 75%         4.000000        4.000000         4.000000       5.000000
# max         5.000000        5.000000         5.000000       5.000000
#
#        Inflight entertainment  On-board service  Leg room service  \
# count           103904.000000     103904.000000     103904.000000
# mean                 3.358158          3.382363          3.351055
# std                  1.332991          1.288354          1.315605
# min                  0.000000          0.000000          0.000000
# 25%                  2.000000          2.000000          2.000000
# 50%                  4.000000          4.000000          4.000000
# 75%                  4.000000          4.000000          4.000000
# max                  5.000000          5.000000          5.000000
#
#        Baggage handling  Checkin service  Inflight service    Cleanliness  \
# count     103904.000000    103904.000000     103904.000000  103904.000000
# mean           3.631833         3.304290          3.640428       3.286351
# std            1.180903         1.265396          1.175663       1.312273
# min            1.000000         0.000000          0.000000       0.000000
# 25%            3.000000         3.000000          3.000000       2.000000
# 50%            4.000000         3.000000          4.000000       3.000000
# 75%            5.000000         4.000000          5.000000       4.000000
# max            5.000000         5.000000          5.000000       5.000000
#
#        Departure Delay in Minutes  Arrival Delay in Minutes
# count               103904.000000             103594.000000
# mean                    14.815618                 15.178678
# std                     38.230901                 38.698682
# min                      0.000000                  0.000000
# 25%                      0.000000                  0.000000
# 50%                      0.000000                  0.000000
# 75%                     12.000000                 13.000000
# max                   1592.000000               1584.000000

# %% [markdown]
# g. Find the Average age of passenger

# %%
print('Average age:',passenger['Age'].mean())
# Out:
# Average age: 39.379706267323684

# %% [markdown]
# h. Arrange the age of passenger in Ascending order

# %%
passenger.sort_values(['Age'])
#sort_values function are used to sort the
# Out:
#            id  Gender      Customer Type  Age   Type of Travel     Class  \
# 45801   76660  Female     Loyal Customer    7  Personal Travel       Eco
# 9556    65984  Female     Loyal Customer    7  Personal Travel       Eco
# 44747   86056  Female     Loyal Customer    7  Personal Travel       Eco
# 20251   65389    Male     Loyal Customer    7  Personal Travel       Eco
# 96926   20596  Female  disloyal Customer    7  Business travel  Eco Plus
# ...       ...     ...                ...  ...              ...       ...
# 81510   50480    Male     Loyal Customer   85  Business travel       Eco
# 35919  125071  Female     Loyal Customer   85  Business travel  Business
# 37138  109731  Female     Loyal Customer   85  Business travel  Business
# 79872  127820  Female  disloyal Customer   85  Business travel  Business
# 28863   37233    Male     Loyal Customer   85  Business travel  Business
#
#        Flight Distance  Inflight wifi service  \
# 45801              547                      3
# 9556              1372                      0
# 44747              447                      3
# 20251              631                      0
# 96926              606                      4
# ...                ...                    ...
# 81510               86                      2
# 35919             3156                      3
# 37138              187                      2
# 79872              862                      1
# 28863             2078                      1
#
#        Departure/Arrival time convenient  Ease of Online booking  ...  \
# 45801                                  2                       3  ...
# 9556                                   4                       0  ...
# 44747                                  4                       3  ...
# 20251                                  3                       0  ...
# 96926                                  0                       4  ...
# ...                                  ...                     ...  ...
# 81510                                  5                       5  ...
# 35919                                  5                       5  ...
# 37138                                  3                       3  ...
# 79872                                  1                       1  ...
# 28863                                  1                       5  ...
#
#        Inflight entertainment  On-board service  Leg room service  \
# 45801                       4                 3                 5
# 9556                        1                 3                 2
# 44747                       4                 3                 5
# 20251                       5                 1                 5
# 96926                       1                 1                 2
# ...                       ...               ...               ...
# 81510                       4                 1                 3
# 35919                       3                 1                 4
# 37138                       3                 5                 4
# 79872                       4                 2                 1
# 28863                       3                 4                 5
#
#        Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 45801                 3                2                 4            4
# 9556                  5                3                 4            1
# 44747                 4                3                 5            4
# 20251                 3                1                 4            5
# 96926                 3                3                 4            1
# ...                 ...              ...               ...          ...
# 81510                 3                2                 2            2
# 35919                 4                3                 3            3
# 37138                 4                4                 1            4
# 79872                 1                5                 1            5
# 28863                 5                4                 4            4
#
#        Departure Delay in Minutes  Arrival Delay in Minutes  \
# 45801                          28                      28.0
# 9556                            0                       0.0
# 44747                          77                      88.0
# 20251                           0                       0.0
# 96926                          22                      24.0
# ...                           ...                       ...
# 81510                          65                      73.0
# 35919                           0                       0.0
# 37138                          17                      11.0
# 79872                          57                      51.0
# 28863                          82                      76.0
#
#                   satisfaction
# 45801  neutral or dissatisfied
# 9556                 satisfied
# 44747  neutral or dissatisfied
# 20251                satisfied
# 96926  neutral or dissatisfied
# ...                        ...
# 81510  neutral or dissatisfied
# 35919  neutral or dissatisfied
# 37138  neutral or dissatisfied
# 79872  neutral or dissatisfied
# 28863                satisfied
#
# [103904 rows x 24 columns]

# %% [markdown]
# i. Find the strength of Female passenger in Airline Passenger Satisfaction Survey

# %%
passenger[passenger['Gender']=='Female']
#Total 52727 Female enteries
#Display only Female entries and their feedback regarding airline service
# Out:
#             id  Gender      Customer Type  Age   Type of Travel     Class  \
# 2       110028  Female     Loyal Customer   26  Business travel  Business
# 3        24026  Female     Loyal Customer   25  Business travel  Business
# 5       111157  Female     Loyal Customer   26  Personal Travel       Eco
# 7        96462  Female     Loyal Customer   52  Business travel  Business
# 8        79485  Female     Loyal Customer   41  Business travel  Business
# ...        ...     ...                ...  ...              ...       ...
# 103893    3397  Female     Loyal Customer   58  Business travel  Business
# 103895   66030  Female  disloyal Customer   24  Business travel       Eco
# 103897  102203  Female     Loyal Customer   60  Business travel  Business
# 103899   94171  Female  disloyal Customer   23  Business travel       Eco
# 103902   54173  Female  disloyal Customer   22  Business travel       Eco
#
#         Flight Distance  Inflight wifi service  \
# 2                  1142                      2
# 3                   562                      2
# 5                  1180                      3
# 7                  2035                      4
# 8                   853                      1
# ...                 ...                    ...
# 103893              296                      3
# 103895             1055                      1
# 103897             1599                      5
# 103899              192                      2
# 103902             1000                      1
#
#         Departure/Arrival time convenient  Ease of Online booking  ...  \
# 2                                       2                       2  ...
# 3                                       5                       5  ...
# 5                                       4                       2  ...
# 7                                       3                       4  ...
# 8                                       2                       2  ...
# ...                                   ...                     ...  ...
# 103893                                  3                       5  ...
# 103895                                  1                       1  ...
# 103897                                  5                       5  ...
# 103899                                  1                       2  ...
# 103902                                  1                       1  ...
#
#         Inflight entertainment  On-board service  Leg room service  \
# 2                            5                 4                 3
# 3                            2                 2                 5
# 5                            1                 3                 4
# 7                            5                 5                 5
# 8                            1                 1                 2
# ...                        ...               ...               ...
# 103893                       3                 3                 3
# 103895                       1                 3                 3
# 103897                       4                 4                 4
# 103899                       2                 3                 1
# 103902                       1                 4                 5
#
#         Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 2                      4                4                 4            5
# 3                      3                1                 4            2
# 5                      4                4                 4            1
# 7                      5                4                 5            4
# 8                      1                4                 1            2
# ...                  ...              ...               ...          ...
# 103893                 3                1                 3            1
# 103895                 5                5                 4            1
# 103897                 4                4                 4            4
# 103899                 4                2                 3            2
# 103902                 1                5                 4            1
#
#         Departure Delay in Minutes  Arrival Delay in Minutes  \
# 2                                0                       0.0
# 3                               11                       9.0
# 5                                0                       0.0
# 7                                4                       0.0
# 8                                0                       0.0
# ...                            ...                       ...
# 103893                           0                      29.0
# 103895                          13                      10.0
# 103897                           9                       7.0
# 103899                           3                       0.0
# 103902                           0                       0.0
#
#                    satisfaction
# 2                     satisfied
# 3       neutral or dissatisfied
# 5       neutral or dissatisfied
# 7                     satisfied
# 8       neutral or dissatisfied
# ...                         ...
# 103893  neutral or dissatisfied
# 103895  neutral or dissatisfied
# 103897                satisfied
# 103899  neutral or dissatisfied
# 103902  neutral or dissatisfied
#
# [52727 rows x 24 columns]

# %% [markdown]
# j. Find those passenger whose age is below 30 or equal to 30

# %%
passenger[passenger['Age']<=30]
# 32757 are passengers whose age below 30 or equal to 30
# Out:
#             id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0        70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1         5047    Male  disloyal Customer   25  Business travel  Business
# 2       110028  Female     Loyal Customer   26  Business travel  Business
# 3        24026  Female     Loyal Customer   25  Business travel  Business
# 5       111157  Female     Loyal Customer   26  Personal Travel       Eco
# ...        ...     ...                ...  ...              ...       ...
# 103895   66030  Female  disloyal Customer   24  Business travel       Eco
# 103899   94171  Female  disloyal Customer   23  Business travel       Eco
# 103901   68825    Male  disloyal Customer   30  Business travel  Business
# 103902   54173  Female  disloyal Customer   22  Business travel       Eco
# 103903   62567    Male     Loyal Customer   27  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 0                   460                      3
# 1                   235                      3
# 2                  1142                      2
# 3                   562                      2
# 5                  1180                      3
# ...                 ...                    ...
# 103895             1055                      1
# 103899              192                      2
# 103901             1995                      1
# 103902             1000                      1
# 103903             1723                      1
#
#         Departure/Arrival time convenient  Ease of Online booking  ...  \
# 0                                       4                       3  ...
# 1                                       2                       3  ...
# 2                                       2                       2  ...
# 3                                       5                       5  ...
# 5                                       4                       2  ...
# ...                                   ...                     ...  ...
# 103895                                  1                       1  ...
# 103899                                  1                       2  ...
# 103901                                  1                       1  ...
# 103902                                  1                       1  ...
# 103903                                  3                       3  ...
#
#         Inflight entertainment  On-board service  Leg room service  \
# 0                            5                 4                 3
# 1                            1                 1                 5
# 2                            5                 4                 3
# 3                            2                 2                 5
# 5                            1                 3                 4
# ...                        ...               ...               ...
# 103895                       1                 3                 3
# 103899                       2                 3                 1
# 103901                       4                 3                 2
# 103902                       1                 4                 5
# 103903                       1                 1                 1
#
#         Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0                      4                4                 5            5
# 1                      3                1                 4            1
# 2                      4                4                 4            5
# 3                      3                1                 4            2
# 5                      4                4                 4            1
# ...                  ...              ...               ...          ...
# 103895                 5                5                 4            1
# 103899                 4                2                 3            2
# 103901                 4                5                 5            4
# 103902                 1                5                 4            1
# 103903                 4                4                 3            1
#
#         Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0                               25                      18.0
# 1                                1                       6.0
# 2                                0                       0.0
# 3                               11                       9.0
# 5                                0                       0.0
# ...                            ...                       ...
# 103895                          13                      10.0
# 103899                           3                       0.0
# 103901                           7                      14.0
# 103902                           0                       0.0
# 103903                           0                       0.0
#
#                    satisfaction
# 0       neutral or dissatisfied
# 1       neutral or dissatisfied
# 2                     satisfied
# 3       neutral or dissatisfied
# 5       neutral or dissatisfied
# ...                         ...
# 103895  neutral or dissatisfied
# 103899  neutral or dissatisfied
# 103901  neutral or dissatisfied
# 103902  neutral or dissatisfied
# 103903  neutral or dissatisfied
#
# [32757 rows x 24 columns]

# %% [markdown]
# 3.Data Processing

# %% [markdown]
# Checking the null values or entry are present or not Airline Passenger Satisfaction Survey

# %%
passenger.isnull().sum()
# Total 310 missing values or entries are found in Airline Passenger Satisfactory Dataset.
#So it neccessary to remove that missing entries or value That affect the other parameter
# Out:
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# satisfaction                           0
# dtype: int64

# %% [markdown]
# Drop the null values are present in Arrival Delay in Minutes coulmns

# %%
passenger=passenger.dropna()
# The dropna() method removes the rows that contains NULL values.
passenger
# The Missing values found in Arrival Delay in minutes so it important to remove that missing values so we remove that missing values in Arrival Delay (in Minutes) data
# Out:
#             id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0        70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1         5047    Male  disloyal Customer   25  Business travel  Business
# 2       110028  Female     Loyal Customer   26  Business travel  Business
# 3        24026  Female     Loyal Customer   25  Business travel  Business
# 4       119299    Male     Loyal Customer   61  Business travel  Business
# ...        ...     ...                ...  ...              ...       ...
# 103899   94171  Female  disloyal Customer   23  Business travel       Eco
# 103900   73097    Male     Loyal Customer   49  Business travel  Business
# 103901   68825    Male  disloyal Customer   30  Business travel  Business
# 103902   54173  Female  disloyal Customer   22  Business travel       Eco
# 103903   62567    Male     Loyal Customer   27  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 0                   460                      3
# 1                   235                      3
# 2                  1142                      2
# 3                   562                      2
# 4                   214                      3
# ...                 ...                    ...
# 103899              192                      2
# 103900             2347                      4
# 103901             1995                      1
# 103902             1000                      1
# 103903             1723                      1
#
#         Departure/Arrival time convenient  Ease of Online booking  ...  \
# 0                                       4                       3  ...
# 1                                       2                       3  ...
# 2                                       2                       2  ...
# 3                                       5                       5  ...
# 4                                       3                       3  ...
# ...                                   ...                     ...  ...
# 103899                                  1                       2  ...
# 103900                                  4                       4  ...
# 103901                                  1                       1  ...
# 103902                                  1                       1  ...
# 103903                                  3                       3  ...
#
#         Inflight entertainment  On-board service  Leg room service  \
# 0                            5                 4                 3
# 1                            1                 1                 5
# 2                            5                 4                 3
# 3                            2                 2                 5
# 4                            3                 3                 4
# ...                        ...               ...               ...
# 103899                       2                 3                 1
# 103900                       5                 5                 5
# 103901                       4                 3                 2
# 103902                       1                 4                 5
# 103903                       1                 1                 1
#
#         Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0                      4                4                 5            5
# 1                      3                1                 4            1
# 2                      4                4                 4            5
# 3                      3                1                 4            2
# 4                      4                3                 3            3
# ...                  ...              ...               ...          ...
# 103899                 4                2                 3            2
# 103900                 5                5                 5            4
# 103901                 4                5                 5            4
# 103902                 1                5                 4            1
# 103903                 4                4                 3            1
#
#         Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0                               25                      18.0
# 1                                1                       6.0
# 2                                0                       0.0
# 3                               11                       9.0
# 4                                0                       0.0
# ...                            ...                       ...
# 103899                           3                       0.0
# 103900                           0                       0.0
# 103901                           7                      14.0
# 103902                           0                       0.0
# 103903                           0                       0.0
#
#                    satisfaction
# 0       neutral or dissatisfied
# 1       neutral or dissatisfied
# 2                     satisfied
# 3       neutral or dissatisfied
# 4                     satisfied
# ...                         ...
# 103899  neutral or dissatisfied
# 103900                satisfied
# 103901  neutral or dissatisfied
# 103902  neutral or dissatisfied
# 103903  neutral or dissatisfied
#
# [103594 rows x 24 columns]

# %%
passenger.drop(['id','Gate location','Baggage handling','Leg room service','Food and drink','On-board service','Inflight entertainment','Arrival Delay in Minutes','Departure Delay in Minutes','Departure/Arrival time convenient','Inflight wifi service'],axis=1,inplace=True)

# %% [markdown]
# Check the overall count or entries of passenger after removing the missing value or null values

# %%
passenger.count()
#AS we Remove the missing values we see the total entries of passengers are decrease
#Previous Entries of passenger are 103904 but after removing missing values the Total entries of passenger are 103594
# That means 310 missing values are totally remove from Airline passenger satisfaction Entries.
# Out:
# Gender                    103594
# Customer Type             103594
# Age                       103594
# Type of Travel            103594
# Class                     103594
# Flight Distance           103594
# Ease of Online booking    103594
# Online boarding           103594
# Seat comfort              103594
# Checkin service           103594
# Inflight service          103594
# Cleanliness               103594
# satisfaction              103594
# dtype: int64

# %% [markdown]
# Find duplicate entries in the survey.

# %%
#duplicated function are used for only count the dupliactes values
passenger[passenger.duplicated()]

#Duplicate handling essential for analysing of accurate and unique data of Airline passenger satisfactory data
# As we check No duplicates entery So our Model are ready for data visualization
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 45054   Female     Loyal Customer   27  Personal Travel       Eco
# 47007     Male     Loyal Customer   48  Personal Travel       Eco
# 51831     Male     Loyal Customer   41  Business travel  Business
# 58156     Male     Loyal Customer   26  Personal Travel       Eco
# 60526     Male     Loyal Customer   45  Personal Travel       Eco
# 61044     Male     Loyal Customer   52  Business travel  Business
# 61383     Male     Loyal Customer   43  Personal Travel       Eco
# 67438   Female     Loyal Customer   41  Business travel  Business
# 67473     Male     Loyal Customer   69  Personal Travel       Eco
# 69120     Male     Loyal Customer   23  Business travel  Business
# 71505   Female     Loyal Customer   65  Personal Travel       Eco
# 79651     Male     Loyal Customer   47  Personal Travel       Eco
# 84194     Male     Loyal Customer   29  Business travel  Business
# 84916   Female  disloyal Customer   20  Business travel       Eco
# 86437   Female  disloyal Customer   25  Business travel  Business
# 87447     Male     Loyal Customer   51  Business travel  Business
# 89658     Male  disloyal Customer   27  Business travel       Eco
# 90386   Female     Loyal Customer   49  Personal Travel       Eco
# 95545     Male     Loyal Customer   43  Business travel  Business
# 95709     Male     Loyal Customer   53  Business travel       Eco
# 97644   Female  disloyal Customer   39  Business travel  Business
# 99184   Female     Loyal Customer   31  Business travel  Business
# 99470   Female     Loyal Customer   56  Business travel  Business
# 100632    Male     Loyal Customer   66  Personal Travel       Eco
# 101361    Male     Loyal Customer   46  Personal Travel       Eco
# 101633  Female     Loyal Customer   53  Business travel  Business
#
#         Flight Distance  Ease of Online booking  Online boarding  \
# 45054               992                       3                3
# 47007               534                       3                3
# 51831               861                       3                5
# 58156               680                       3                3
# 60526               438                       3                3
# 61044              3826                       2                5
# 61383              2475                       3                1
# 67438              2246                       1                5
# 67473               106                       1                1
# 69120              1671                       1                5
# 71505               507                       3                4
# 79651              1074                       2                2
# 84194              2402                       5                4
# 84916               589                       2                2
# 86437               925                       5                5
# 87447              2586                       3                4
# 89658              1197                       1                1
# 90386               594                       2                3
# 95545              2454                       4                4
# 95709               679                       1                3
# 97644               255                       2                2
# 99184              3845                       1                5
# 99470              1020                       5                5
# 100632              404                       1                1
# 101361              236                       3                3
# 101633             2586                       5                5
#
#         Seat comfort  Checkin service  Inflight service  Cleanliness  \
# 45054              4                3                 4            4
# 47007              1                3                 5            1
# 51831              5                5                 3            5
# 58156              2                4                 5            2
# 60526              2                1                 3            2
# 61044              4                5                 4            3
# 61383              1                1                 5            1
# 67438              5                3                 4            3
# 67473              2                4                 5            2
# 69120              5                3                 4            5
# 71505              4                4                 4            3
# 79651              3                5                 5            3
# 84194              4                4                 4            4
# 84916              3                2                 3            3
# 86437              2                4                 5            2
# 87447              4                4                 3            4
# 89658              2                3                 3            2
# 90386              3                3                 4            1
# 95545              4                4                 5            4
# 95709              3                1                 4            3
# 97644              2                3                 4            2
# 99184              5                4                 4            5
# 99470              4                4                 5            4
# 100632             4                3                 4            4
# 101361             4                3                 4            4
# 101633             5                5                 5            5
#
#                    satisfaction
# 45054   neutral or dissatisfied
# 47007   neutral or dissatisfied
# 51831                 satisfied
# 58156   neutral or dissatisfied
# 60526   neutral or dissatisfied
# 61044                 satisfied
# 61383   neutral or dissatisfied
# 67438                 satisfied
# 67473   neutral or dissatisfied
# 69120                 satisfied
# 71505   neutral or dissatisfied
# 79651   neutral or dissatisfied
# 84194                 satisfied
# 84916   neutral or dissatisfied
# 86437                 satisfied
# 87447                 satisfied
# 89658   neutral or dissatisfied
# 90386   neutral or dissatisfied
# 95545                 satisfied
# 95709   neutral or dissatisfied
# 97644   neutral or dissatisfied
# 99184                 satisfied
# 99470                 satisfied
# 100632  neutral or dissatisfied
# 101361  neutral or dissatisfied
# 101633                satisfied

# %% [markdown]
# Encoding
# Types of Encoding:- 1. Label or Ordinal Encoding :-  Ordinal Encoding:- In
#                     ordinal encoding, each unique category value is assigned an integer value.This ordinal encoding transform is available in the scikit-learn Python machine learning library via the OrdinalEncoder class.
#                     2. One hot Encoding (get dummies):- One hot encoding is a technique that we use to represent categorical variables as numerical values in a machine learning model.

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
x=passenger.iloc[:,:-1]
x
# iloc:- The iloc() function is an indexed-based selecting method which means that we have to pass an integer index in the method to select a specific row/column
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 0         Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1         Male  disloyal Customer   25  Business travel  Business
# 2       Female     Loyal Customer   26  Business travel  Business
# 3       Female     Loyal Customer   25  Business travel  Business
# 4         Male     Loyal Customer   61  Business travel  Business
# ...        ...                ...  ...              ...       ...
# 103899  Female  disloyal Customer   23  Business travel       Eco
# 103900    Male     Loyal Customer   49  Business travel  Business
# 103901    Male  disloyal Customer   30  Business travel  Business
# 103902  Female  disloyal Customer   22  Business travel       Eco
# 103903    Male     Loyal Customer   27  Business travel  Business
#
#         Flight Distance  Ease of Online booking  Online boarding  \
# 0                   460                       3                3
# 1                   235                       3                3
# 2                  1142                       2                5
# 3                   562                       5                2
# 4                   214                       3                5
# ...                 ...                     ...              ...
# 103899              192                       2                2
# 103900             2347                       4                4
# 103901             1995                       1                1
# 103902             1000                       1                1
# 103903             1723                       3                1
#
#         Seat comfort  Checkin service  Inflight service  Cleanliness
# 0                  5                4                 5            5
# 1                  1                1                 4            1
# 2                  5                4                 4            5
# 3                  2                1                 4            2
# 4                  5                3                 3            3
# ...              ...              ...               ...          ...
# 103899             2                2                 3            2
# 103900             5                5                 5            4
# 103901             5                5                 5            4
# 103902             1                5                 4            1
# 103903             1                4                 3            1
#
# [103594 rows x 12 columns]

# %% [markdown]
# Perform Ordinal Encoding on x variable

# %%
df=OrdinalEncoder()#As we perform encoding
# In this label encoding can be perform
x[['Gender','Customer Type','Type of Travel','Class']]=df.fit_transform(x[['Gender','Customer Type','Type of Travel','Class']])
x.tail()
# Out:
#         Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 103899     0.0            1.0   23             0.0    1.0              192
# 103900     1.0            0.0   49             0.0    0.0             2347
# 103901     1.0            1.0   30             0.0    0.0             1995
# 103902     0.0            1.0   22             0.0    1.0             1000
# 103903     1.0            0.0   27             0.0    0.0             1723
#
#         Ease of Online booking  Online boarding  Seat comfort  \
# 103899                       2                2             2
# 103900                       4                4             5
# 103901                       1                1             5
# 103902                       1                1             1
# 103903                       3                1             1
#
#         Checkin service  Inflight service  Cleanliness
# 103899                2                 3            2
# 103900                5                 5            4
# 103901                5                 5            4
# 103902                5                 4            1
# 103903                4                 3            1

# %% [markdown]
# Perform Label Encoding on target y variable (satisfaction) column

# %%
passenger['satisfaction']=passenger['satisfaction'].map({'satisfied':1,'neutral or dissatisfied':0})
#We know the target variable is only in numerical form not in categorical data
# So we change into as numerical data for training and testing purpose
# As we see the satisfication data are show in numerical form like satisfied show '1' and  netural or dissatisfied show '0'

# %%
y=passenger.iloc[:,-1]
y
#Target variable y is satisfaction either it is 0 0r 1
# Out:
# 0         0
# 1         0
# 2         1
# 3         0
# 4         1
#          ..
# 103899    0
# 103900    1
# 103901    0
# 103902    0
# 103903    0
# Name: satisfaction, Length: 103594, dtype: int64

# %% [markdown]
# 4. Data Visualization to understand the distribution of various Airline features

# %% [markdown]
# Perform EDA
#  Exploratory Data Analysis (EDA) is an approach that is used to analyze the data and discover trends, patterns, or check assumptions in data with the help of statistical summaries and graphical representations.

# %% [markdown]
# **Boxplo**t :-It is a type of chart that depicts a group of numerical data through their quartiles. It is a simple way to visualize the shape of our data. It makes comparing characteristics of data between categories very easy.

# %%
sns.boxplot(x=passenger['Ease of Online booking'])
# That show Ease of booking rating medium range is 3 and minimum and maximum are 0 and 5
# Out:
# <Axes: xlabel='Ease of Online booking'>

# %%
sns.boxplot(x=passenger['Flight Distance'])
# Flight Distance are show outliers.
# Out:
# <Axes: xlabel='Flight Distance'>

# %%
sns.boxplot(x=passenger['Checkin service'])
# That column display the outlier so it is necessary to remove that outliers.
# Out:
# <Axes: xlabel='Checkin service'>

# %% [markdown]
# Check skewness in Given Dataset
#
# Skewness :- Skewness tell us the direction of outliers.Skewness is an important statistical technique that helps to determine asymmetrical behavior than of the frequency distribution, or more precisely, the lack of symmetry of tails both left and right of the frequency curve.
#
#
#
#
#
# **Three types of Skewness are**
#
# a. positive skewness
#
# b. negative skewness
#
# c. no or zero skewness

# %%
passenger.describe()
# In that Dataset mean < median < mode
# So, Its a negatively skew (left tail is longer)
# Out:
#                  Age  Flight Distance  Ease of Online booking  \
# count  103594.000000    103594.000000           103594.000000
# mean       39.380466      1189.325202                2.756984
# std        15.113125       997.297235                1.398934
# min         7.000000        31.000000                0.000000
# 25%        27.000000       414.000000                2.000000
# 50%        40.000000       842.000000                3.000000
# 75%        51.000000      1743.000000                4.000000
# max        85.000000      4983.000000                5.000000
#
#        Online boarding   Seat comfort  Checkin service  Inflight service  \
# count    103594.000000  103594.000000    103594.000000     103594.000000
# mean          3.250497       3.439765         3.304323          3.640761
# std           1.349433       1.318896         1.265396          1.175603
# min           0.000000       0.000000         0.000000          0.000000
# 25%           2.000000       2.000000         3.000000          3.000000
# 50%           3.000000       4.000000         3.000000          4.000000
# 75%           4.000000       5.000000         4.000000          5.000000
# max           5.000000       5.000000         5.000000          5.000000
#
#          Cleanliness   satisfaction
# count  103594.000000  103594.000000
# mean        3.286397       0.433394
# std         1.312194       0.495546
# min         0.000000       0.000000
# 25%         2.000000       0.000000
# 50%         3.000000       0.000000
# 75%         4.000000       1.000000
# max         5.000000       1.000000

# %% [markdown]
# **Outliers**:- An outlier is a data point that differs significantly from other observations.Outliers are detect by using IQR method stands for interquartile range, which is the difference between q3 (75th percentile) and q1 (25th percentile). The IQR method computes lower bound and upper bound to identify outliers.
# IQR = Q3 - Q1

# %%
Q1=passenger.quantile(0.25)#first quartile
Q3=passenger.quantile(0.75)#third quartile
IQR= Q3- Q1
IQR
# Out:
# Age                         24.0
# Flight Distance           1329.0
# Ease of Online booking       2.0
# Online boarding              2.0
# Seat comfort                 3.0
# Checkin service              1.0
# Inflight service             2.0
# Cleanliness                  2.0
# satisfaction                 1.0
# dtype: float64

# %% [markdown]
# **Formula for Removing Outliers** = The outliers are the points lying beyond the upper boundary of Q3 +1.5 IQR and the lower boundary of Q1 - 1.5 IQR.

# %%
passenger=passenger[~((passenger<(Q1-1.5 * IQR))|(passenger>(Q3+1.5 * IQR))).any(axis=1)]
passenger.shape
# The total 88665 rows are remove by outliers
# Out:
# (88665, 13)

# %% [markdown]
# **Pie Chart**
# :- A pie chart is defined as a circular chart with multiple divisions where each
#
# division shows the contribution of each value to the total value.

# %%
passenger['Customer Type'].value_counts().plot(kind='pie',figsize=(10,5),autopct='%.2f%%',explode=(0,0.07),colors=['#261768','#AEA4FA'])
plt.title("Customer type its loyal or disloyal")
plt.ylabel("Number of passengers")
plt.xlabel("Number of Loyal or disloyal customer");
# 81.66% customer are loyal and 18.34% are disloyal
# Its show the majority of Loyal Customer than the disloyal customer

# %%
passenger.Gender.value_counts().plot(kind='pie',figsize=(9,4),autopct='%.2f%%',explode=(0,0.05),colors=['#EA5F89','#F7B7A3'])
plt.title("Check strength of Male and Female")
plt.ylabel("Number of passengers")
plt.xlabel("Gender(Male and Female)");
# 50.75% Female are take benefit of Airline service
# Female customers strength (50.75% ) are more than Male customers (49.25%)

# %%
passenger.Class.value_counts().plot(kind='pie',figsize=(9,4),autopct='%.2f%%',explode=(0,0,0.2))
plt.title("Distribution of Class")
plt.ylabel("Class")
plt.xlabel("Airline provided Class");
# Business Class are 49.26% full
#Eco Class are 43.92
#Eco Plus Class are 6.82%
#By that we considered that Maximum Passenger are using Business Class Service than the other Eco and Eco Plus Class.
#Least use Class are Eco Plus Class than other two Class.

# %% [markdown]
# **Bar plot** :- A bar graph is a graphical representation of data in which we can highlight the category with particular shapes like a rectangle

# %%
passenger.Class.value_counts().plot(kind='bar',figsize=(9,4),color=['purple','pink','grey'])
plt.title("Class for Aeroplane")
plt.ylabel("Number of passengers")
plt.xlabel("Number of class that provided by airline service provider");
#Same output The Business Class has more preferable by customer point of view
# Eco Plus class are very less prefer by passenger

# %%
passenger['Type of Travel'].value_counts().plot(kind='bar',figsize=(10,5),color=['pink','green'])
plt.title("Different Types of Travel Services in Aeroplane")
plt.ylabel("Number of Passengers")
plt.xlabel("Type of Travel")
#As We see maximum passengers are go to business travel and minimum passengers are go through personal travel
# Out:
# Text(0.5, 0, 'Type of Travel')

# %% [markdown]
# **HeatMap** :- Heat Maps are graphical representations of data that utilize color-coded systems. The primary purpose of Heat Maps is to better visualize the volume of locations/events within a dataset and assist in directing viewers towards areas on data visualizations that matter most.

# %%
plt.figure(figsize=(12,5))
c=passenger.corr()
sns.heatmap(c,cmap="GnBu",annot=True)
c
# Dark color show they are strongly correlated and light dark that show they are weakly correlated and whitis color show no correlation.
# Out:
#                              Age  Flight Distance  Ease of Online booking  \
# Age                     1.000000         0.100650                0.020905
# Flight Distance         0.100650         1.000000                0.067345
# Ease of Online booking  0.020905         0.067345                1.000000
# Online boarding         0.221765         0.222907                0.414515
# Seat comfort            0.177122         0.168744                0.031490
# Checkin service         0.024439         0.054081                0.002508
# Inflight service       -0.060846         0.054327                0.037750
# Cleanliness             0.068475         0.105914                0.017326
# satisfaction            0.143414         0.305587                0.182827
#
#                         Online boarding  Seat comfort  Checkin service  \
# Age                            0.221765      0.177122         0.024439
# Flight Distance                0.222907      0.168744         0.054081
# Ease of Online booking         0.414515      0.031490         0.002508
# Online boarding                1.000000      0.413108         0.161320
# Seat comfort                   0.413108      1.000000         0.153148
# Checkin service                0.161320      0.153148         1.000000
# Inflight service               0.061764      0.057826         0.188005
# Cleanliness                    0.324250      0.680805         0.146230
# satisfaction                   0.510176      0.347532         0.193158
#
#                         Inflight service  Cleanliness  satisfaction
# Age                            -0.060846     0.068475      0.143414
# Flight Distance                 0.054327     0.105914      0.305587
# Ease of Online booking          0.037750     0.017326      0.182827
# Online boarding                 0.061764     0.324250      0.510176
# Seat comfort                    0.057826     0.680805      0.347532
# Checkin service                 0.188005     0.146230      0.193158
# Inflight service                1.000000     0.077107      0.227571
# Cleanliness                     0.077107     1.000000      0.297801
# satisfaction                    0.227571     0.297801      1.000000

# %% [markdown]
# **Scatter plot** :- A scatter plot (aka scatter chart, scatter graph) uses dots to represent values for two different numeric variables. The position of each dot on the horizontal and vertical axis indicates values for an individual data point. Scatter plots are used to observe relationships between variable

# %%
plt.figure(figsize=(8,6))
plt.scatter(passenger['Inflight service'],passenger['Checkin service'],alpha=0.5,color='r')
plt.title("Inflight Service Vs. Checkin Service Rating")
plt.xlabel("Inflight Service Rating")
plt.ylabel("Checkin Service Rating")
plt.show()
# That show a relationship between Inflight Service and Checkin Service who they are related to each other

# %% [markdown]
# **Count Plot** :- The countplot is used to represent the occurrence(counts) of the observation present in the categorical variable. It uses the concept of a bar chart for the visual depiction

# %%
sns.countplot(x='Gender',data=passenger,hue='Gender',palette='rocket')
plt.title("Distribuiton of Gender")
plt.show()
# Female customer as more strength than Male customer

# %% [markdown]
# **Hist Plot** :- A histogram is a graph used to represent the frequency distribution of a few data points of one variable.It can help detect any unusual observations (outliers) or any gaps in the data

# %%
sns.histplot(passenger['Age'],bins=20,kde=True)
plt.title("Distribution of age")
plt.show()
# By graph its clear that maximum passenger age between 38 to 42

# %% [markdown]
# **Displot**:-  Distribution plots show how a variable (or multiple variables) is distributed. Seaborn provides many different distribution data visualization functions that include creating histograms or kernel density estimates.

# %%
sns.displot(data=passenger, x='Inflight service',kde=True)
# Show the highest rating for Inflight Service is 4 and least rating is 1

# %% [markdown]
# **Model Testing and Training**
#
# Train and Test datasets are the two key concepts of machine learning, where the training dataset is used to fit the model, and the test dataset is used to evaluate the model.

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=1)
# Training dataset 75% and 25% for testing of airline passenger satisification dataset

# %% [markdown]
# **Perform Logistic Regression**
#
# **Logistic regression** :- Logistic regression is a data analysis technique that uses mathematics to find the relationships between two data factors. It then uses this relationship to predict the value of one of those factors based on the other. The prediction usually has a finite number of outcomes, like yes or no.

# %%
#Perform Logistic Regression
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()
model.fit(xtrain,ytrain)
# Fit :-Model fitting is a measure of how well a machine learning model generalizes to similar data to that on which it was trained. A model that is well-fitted produces more accurate outcomes.
# Out:
# LogisticRegression()

# %%
ypred=model.predict(xtest)
ypred
#Predict :- Prediction” refers to the output of an algorithm after it has been trained on a historical dataset and applied to new data when forecasting the likelihood of a particular outcome
# Out:
# array([1, 0, 0, ..., 1, 1, 1])

# %% [markdown]
# **Classification of Model**
#
# Predictive Modeling
#
# The Classification algorithm is a Supervised Learning technique that is used to identify the category of new observations on the basis of training data.his technique can be performed on structured or unstructured data and its main goal is to identify the category or class to which a new data will fall under.

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# Dispaly Classification Report

# %%
print(classification_report(ytest,ypred))
#A classification report is a performance evaluation metric in machine learning. It is used to show the precision, recall, F1 Score, and support of your trained classification model.
#Precision :- Precision is defined as the ratio of true positives to the sum of true and false positives.
#Recall :- Recall is defined as the ratio of true positives to the sum of true positives and false negatives.
# F1 Score :- The F1 is the weighted harmonic mean of precision and recall. The closer the value of the F1 score is to 1.0, the better the expected performance of the model is.
# Support :- Support is the number of actual occurrences of the class in the dataset. It doesn’t vary between models, it just diagnoses the performance evaluation process
#Note
# If F1 score are high(better) means model are best
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.82      0.83     11807
#            1       0.77      0.79      0.78      8912
#
#     accuracy                           0.81     20719
#    macro avg       0.80      0.81      0.80     20719
# weighted avg       0.81      0.81      0.81     20719

# %% [markdown]
# Display Confusion matrix

# %%
print(confusion_matrix(ytest,ypred))
#The confusion matrix is a matrix used to determine the performance of the classification models for a given set of test data.
#The matrix is divided into two dimensions, that are predicted values and actual values along with the total number of predictions.
#Predicted values are those values, which are predicted by the model, and actual values are the true values for the given observations.
#The above  has the following cases:

#True Negative: Model has given prediction No, and the real or actual value was also No.
#True Positive: The model has predicted yes, and the actual value was also true.
#False Negative: The model has predicted no, but the actual value was Yes, it is also called as Type-II error.
#False Positive: The model has predicted Yes, but the actual value was No. It is also called a Type-I error.
# Out:
# [[9711 2096]
#  [1887 7025]]

# %% [markdown]
# Display the Training Accuracy of Model

# %%
model.score(xtrain,ytrain)
# training accuracy
# Out:
# 0.8110889894419306

# %% [markdown]
# Display the Testing Accuracy of Model

# %%
model.score(xtest,ytest)
#testing accuracy
# Out:
# 0.8077609923258845

# %% [markdown]
# Model Prediction by User.

# %%
gender=int(input("Enter the Gender (For Male 1/For Female 0): "))
customer_type = int(input('\nEnter the customer Type (For Loyal customer 0, For Disloyal customer 1): '))
age=int(input('\nEnter age of passenger: '))
type_of_travel=int(input("\nEnter type of travel for aeroplane (whether it is personal hit 1/Business hit 0): "))
class_p=int(input("\nEnter the class (For Business enter 0 / For Eco enter 1/For Eco plus enter 2): "))
flight_distance=float(input("\nEnter Flight Distance(in miles): "))
ease_of_online_booking=int(input("\nEnter Ease of Online Booking rating (0 to 5): "))
online_boarding=int(input("\nEnter Online boarding service rating (1 to 5):"))
seat_comfort=int(input("\nEnter Seat Comfort rating (1 to 5): "))
checkin_service = int(input("\nEnter Check- in Service rating (1 to 5): "))
cleanliness = int(input("\nEnter Cleanliness rating (1 to 5): "))
inflight_service = int(input("\nEnter Inflight Service rating ( 1 to 5): "))

satisfy_data = [[gender,customer_type,age,type_of_travel,class_p,flight_distance,ease_of_online_booking,online_boarding,seat_comfort,checkin_service,cleanliness,inflight_service]]
prediction=model.predict(satisfy_data)
print("\n\n")
if prediction==1:
    print("****  The Passenger is Satisfied by Airline Service   ****")
else:
    print("**** The Passenger is Neutral/Dissatisfied by Airline Service ****")
# Out:
# Enter the Gender (For Male 1/For Female 0): 0
#
# Enter the customer Type (For Loyal customer 0, For Disloyal customer 1): 1
#
# Enter age of passenger: 19
#
# Enter type of travel for aeroplane (whether it is personal hit 1/Business hit 0): 0
#
# Enter the class (For Business enter 0 / For Eco enter 1/For Eco plus enter 2): 0
#
# Enter Flight Distance(in miles): 1242
#
# Enter Ease of Online Booking rating (0 to 5): 2
#
# Enter Online boarding service rating (1 to 5):3
#
# Enter Seat Comfort rating (1 to 5): 2
#
# Enter Check- in Service rating (1 to 5): 2
#
# Enter Cleanliness rating (1 to 5): 2
#
# Enter Inflight Service rating ( 1 to 5): 2
#
#
#
# ****  The Passenger is Satisfied by Airline Service   ****

# %% [markdown]
# **Conclusion**:- In this project , emphasizes the critical role of passenger satisfaction in the airline industry. By understanding the drivers of satisfaction and making data-informed decisions, airlines can enhance their services, build stronger customer relationships, and remain competitive in a rapidly evolving market. Improving passenger satisfaction will undoubtedly lead to higher customer retention rates and increased profitability, ultimately contributing to the long-term success of airlines.
